# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirtha-Raja-Rajeswari/NLP_Lab/blob/main/NLP_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CATEGORY 1 : Text Preprocessing**

# %%
import nltk
from nltk.corpus import brown
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_218/2255901070.py in <cell line: 0>()
# ----> 1 import nltk
#       2 from nltk.corpus import brown
#       3 from nltk.tokenize import word_tokenize
#       4 from nltk.corpus import stopwords
#       5 from nltk.stem import PorterStemmer
#
# /usr/local/lib/python3.12/dist-packages/nltk/__init__.py in <module>
#     178     from nltk import cluster
#     179
# --> 180 from nltk.downloader import download, download_shell
#     181
#     182 try:
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in <module>
#    2473
#    2474 # Aliases
# -> 2475 _downloader = Downloader()
#    2476 download = _downloader.download
#    2477
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in __init__(self, server_index_url, download_dir)
#     513         # decide where we're going to save things to.
# ...

# %% [markdown]
# # **Brown Corpus**

# %%
print("Total sentences:", len(brown.sents()))
print("Total words:", len(brown.words()))
# Out:
# Total sentences: 57340
# Total words: 1161192

# %%
words = brown.words(categories='news')
print(words)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
text = " ".join(words)
print(text[:500])
# Out:
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted . The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to invest

# %% [markdown]
# **Normalization**

# %%
normalized_text = text.lower()
print(normalized_text[:500])
# Out:
# the fulton county grand jury said friday an investigation of atlanta's recent primary election produced `` no evidence '' that any irregularities took place . the jury further said in term-end presentments that the city executive committee , which had over-all charge of the election , `` deserves the praise and thanks of the city of atlanta '' for the manner in which the election was conducted . the september-october term jury had been charged by fulton superior court judge durwood pye to invest

# %% [markdown]
# **Tokenization**

# %%
tokens = word_tokenize(normalized_text)
print(tokens[:30])
# Out:
# ['the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', 'atlanta', "'s", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', '``', 'that', 'any', 'irregularities', 'took', 'place', '.', 'the', 'jury', 'further', 'said']

# %% [markdown]
# **Stop Word Removal**

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = []

for word in tokens:
    if word.isalpha() and word not in stop_words:
        filtered_tokens.append(word)

print(filtered_tokens[:30])
# Out:
# ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'atlanta', 'recent', 'primary', 'election', 'produced', 'evidence', 'irregularities', 'took', 'place', 'jury', 'said', 'presentments', 'city', 'executive', 'committee', 'charge', 'election', 'deserves', 'praise', 'thanks', 'city', 'atlanta', 'manner']

# %% [markdown]
# **Stemming**

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words[:30])
# Out:
# ['fulton', 'counti', 'grand', 'juri', 'said', 'friday', 'investig', 'atlanta', 'recent', 'primari', 'elect', 'produc', 'evid', 'irregular', 'took', 'place', 'juri', 'said', 'present', 'citi', 'execut', 'committe', 'charg', 'elect', 'deserv', 'prais', 'thank', 'citi', 'atlanta', 'manner']

# %% [markdown]
# **Lemmatization**

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words[:30])
# Out:
# ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'atlanta', 'recent', 'primary', 'election', 'produced', 'evidence', 'irregularity', 'took', 'place', 'jury', 'said', 'presentment', 'city', 'executive', 'committee', 'charge', 'election', 'deserves', 'praise', 'thanks', 'city', 'atlanta', 'manner']

# %% [markdown]
# # **Universal Dependencies English Treebank**

# %%
nltk.download('udhr')
nltk.download('dependency_treebank')
# Out:
# [nltk_data] Downloading package udhr to /root/nltk_data...
# [nltk_data]   Package udhr is already up-to-date!
# [nltk_data] Downloading package dependency_treebank to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/dependency_treebank.zip.
# True

# %%
from nltk.corpus import dependency_treebank
from nltk.stem import SnowballStemmer

# %%
print("Total sentences:", len(dependency_treebank.sents()))
print("Total words:", len(dependency_treebank.words()))
# Out:
# Total sentences: 3914
# Total words: 94084

# %%
words = brown.words(categories='religion')
print(words)
# Out:
# ['As', 'a', 'result', ',', 'although', 'we', 'still', ...]

# %%
text = " ".join(words)
print(text[:500])
# Out:
# As a result , although we still make use of this distinction , there is much confusion as to the meaning of the basic terms employed . Just what is meant by `` spirit '' and by `` matter '' ? ? The terms are generally taken for granted as though they referred to direct and axiomatic elements in the common experience of all . Yet in the contemporary context this is precisely what one must not do . For in the modern world neither `` spirit '' nor `` matter '' refer to any generally agreed-upon ele

# %% [markdown]
# **Normalization**

# %%
normalized_text = text.lower()
print(normalized_text[:500])
# Out:
# as a result , although we still make use of this distinction , there is much confusion as to the meaning of the basic terms employed . just what is meant by `` spirit '' and by `` matter '' ? ? the terms are generally taken for granted as though they referred to direct and axiomatic elements in the common experience of all . yet in the contemporary context this is precisely what one must not do . for in the modern world neither `` spirit '' nor `` matter '' refer to any generally agreed-upon ele

# %% [markdown]
# **Tokanization**

# %%
tokens = word_tokenize(normalized_text)
print(tokens[:30])
# Out:
# ['as', 'a', 'result', ',', 'although', 'we', 'still', 'make', 'use', 'of', 'this', 'distinction', ',', 'there', 'is', 'much', 'confusion', 'as', 'to', 'the', 'meaning', 'of', 'the', 'basic', 'terms', 'employed', '.', 'just', 'what', 'is']

# %% [markdown]
# **Stop Word removal**

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = []

for word in tokens:
    if word.isalpha() and word not in stop_words:
        filtered_tokens.append(word)

print(filtered_tokens[:30])
# Out:
# ['result', 'although', 'still', 'make', 'use', 'distinction', 'much', 'confusion', 'meaning', 'basic', 'terms', 'employed', 'meant', 'spirit', 'matter', 'terms', 'generally', 'taken', 'granted', 'though', 'referred', 'direct', 'axiomatic', 'elements', 'common', 'experience', 'yet', 'contemporary', 'context', 'precisely']

# %% [markdown]
# **Stemming**

# %%
stemmer = SnowballStemmer('english')
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words[:30])
# Out:
# ['result', 'although', 'still', 'make', 'use', 'distinct', 'much', 'confus', 'mean', 'basic', 'term', 'employ', 'meant', 'spirit', 'matter', 'term', 'general', 'taken', 'grant', 'though', 'refer', 'direct', 'axiomat', 'element', 'common', 'experi', 'yet', 'contemporari', 'context', 'precis']

# %% [markdown]
# **Lemmatization**

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words[:30])
# Out:
# ['result', 'although', 'still', 'make', 'use', 'distinction', 'much', 'confusion', 'meaning', 'basic', 'term', 'employed', 'meant', 'spirit', 'matter', 'term', 'generally', 'taken', 'granted', 'though', 'referred', 'direct', 'axiomatic', 'element', 'common', 'experience', 'yet', 'contemporary', 'context', 'precisely']

# %% [markdown]
# # **Stemming Algorithm**

# %%
def simple_stemmer(word):

    word = word.lower()
    suffixes = ["ing", "ed", "ly", "es", "s"]
    for suffix in suffixes:
        if word.endswith(suffix) and len(word) > len(suffix):
            return word[:-len(suffix)]
    return word

words = ["Running", "Played", "Happily", "Cars", "Studies"]
stemmed_words = []

for word in words:
    stemmed_words.append(simple_stemmer(word))

print("Original words:", words)
print("Stemmed words :", stemmed_words)
# Out:
# Original words: ['Running', 'Played', 'Happily', 'Cars', 'Studies']
# Stemmed words : ['runn', 'play', 'happi', 'car', 'studi']

# %% [markdown]
# # **Lemmataization Algorithm**

# %%
def simple_lemmatizer(word):
    word = word.lower()
    lemma_dict = {
        "children": "child",
        "mice": "mouse",
        "better": "good",
        "best": "good",
        "was": "be",
        "were": "be",
        "went": "go",
        "feet": "foot"
    }

    if word in lemma_dict:
        return lemma_dict[word]

    if word.endswith("ies"):
        return word[:-3] + "y"
    elif word.endswith("ing"):
        return word[:-3]
    elif word.endswith("ed"):
        return word[:-2]
    elif word.endswith("s"):
        return word[:-1]

    return word

words = ["children", "running", "studies", "better", "played", "cars", "went"]
lemmatized_words = [simple_lemmatizer(word) for word in words]

print("Original words :", words)
print("Lemmatized words:", lemmatized_words)
# Out:
# Original words : ['children', 'running', 'studies', 'better', 'played', 'cars', 'went']
# Lemmatized words: ['child', 'runn', 'study', 'good', 'play', 'car', 'go']

# %% [markdown]
# **CATEGORY 2 : Entropy, Cross Entropy and Perplexity**

# %%
import numpy as np

sentences = [
    "the cat sits on the mat",
    "the dog sits on the rug",
    "the cat sleeps on the mat"
]

words = np.array(" ".join(sentences).split())
vocab, counts = np.unique(words, return_counts=True)
P = counts / len(words)

entropy = -np.sum(P * np.log2(P))
cross_entropy = -np.sum(P * np.log2(1/len(vocab)))
perplexity = 2 ** entropy

print("Entropy:", entropy)
print("Cross Entropy:", cross_entropy)
print("Perplexity:", perplexity)
# Out:
# Entropy: 2.7107770844150676
# Cross Entropy: 3.0
# Perplexity: 6.5467418158303285

# %% [markdown]
# **CATEGORY 3 : Rule Based Morphological Analyzer**

# %%
import numpy as np

sentences = [
    "The boys are playing happily",
    "She walked quickly to the store",
    "They are rewriting the assignment"
]

words = " ".join(sentences).lower().split()

prefixes = ["un","re","in","dis"]
suffixes = ["ing","ed","ly","s","es"]

print(f"{'Word':<12} | {'Root':<12} | {'Affix':<8} | {'Type'}")
print("-"*45)

for w in words:
    for p in prefixes:
        if w.startswith(p) and len(w) > len(p)+2:
            print(f"{w:<12} | {w[len(p):]:<12} | {p:<8} | Prefix")
            break
    else:
        for s in suffixes:
            if w.endswith(s) and len(w) > len(s)+1:
                print(f"{w:<12} | {w[:-len(s)]:<12} | {s:<8} | Suffix")
                break
        else:
            print(f"{w:<12} | {w:<12} | {'-':<8} | Root")
# Out:
# Word         | Root         | Affix    | Type
# ---------------------------------------------
# the          | the          | -        | Root
# boys         | boy          | s        | Suffix
# are          | are          | -        | Root
# playing      | play         | ing      | Suffix
# happily      | happi        | ly       | Suffix
# she          | she          | -        | Root
# walked       | walk         | ed       | Suffix
# quickly      | quick        | ly       | Suffix
# to           | to           | -        | Root
# the          | the          | -        | Root
# store        | store        | -        | Root
# they         | they         | -        | Root
# are          | are          | -        | Root
# rewriting    | writing      | re       | Prefix
# the          | the          | -        | Root
# assignment   | assignment   | -        | Root

# %% [markdown]
# **CATEGORY 4 : Finite State Automata Based Morphological Analyzer**

# %%
sentences = [
    "The boys are playing happily",
    "She walked quickly to the store",
    "They are rewriting the assignment"
]

words = " ".join(sentences).lower().split()

prefixes = ["un","re","in","dis"]
suffixes = ["ing","ed","ly","s","es","able"]

print(f"{'Word':<12} | {'Root':<12} | {'Affix':<8} | {'Type'}")
print("-"*45)

for word in words:
    state = "START"

    for p in prefixes:
        if word.startswith(p):
            root = word[len(p):]
            print(f"{word:<12} | {root:<12} | {p:<8} | Prefix")
            state = "PREFIX_FOUND"
            break

    if state == "START":
        for s in suffixes:
            if word.endswith(s):
                root = word[:-len(s)]
                print(f"{word:<12} | {root:<12} | {s:<8} | Suffix")
                state = "SUFFIX_FOUND"
                break

    if state == "START":
        print(f"{word:<12} | {word:<12} | {'-':<8} | Root")
# Out:
# Word         | Root         | Affix    | Type
# ---------------------------------------------
# the          | the          | -        | Root
# boys         | boy          | s        | Suffix
# are          | are          | -        | Root
# playing      | play         | ing      | Suffix
# happily      | happi        | ly       | Suffix
# she          | she          | -        | Root
# walked       | walk         | ed       | Suffix
# quickly      | quick        | ly       | Suffix
# to           | to           | -        | Root
# the          | the          | -        | Root
# store        | store        | -        | Root
# they         | they         | -        | Root
# are          | are          | -        | Root
# rewriting    | writing      | re       | Prefix
# the          | the          | -        | Root
# assignment   | assignment   | -        | Root
# capable      | cap          | able     | Suffix
# this         | thi          | s        | Suffix

# %% [markdown]
# **CATEGORY 5 : Unigram Language Model and Laplace smoothing**

# %%
import numpy as np

sentences = [
    "the cat sits on the mat",
    "the dog sits on the rug",
    "the cat sleeps on the mat"
]

words = np.array(" ".join(sentences).split())
vocab, counts = np.unique(words, return_counts=True)
N = len(words)
V = len(vocab)

print(f"{'Word':<12} | {'count':<12} | {'Unigram':<22} | {'Laplacian':<12}")
print("-"*70)

for w, c in zip(vocab, counts):
    prob = c / (N + V)
    lap = (c + 1) / (N + V)
    print(f"{w:<12} | {c:<12} | {prob:<22} | {lap:<12}")
# Out:
# Word         | count        | Unigram                | Laplacian
# ----------------------------------------------------------------------
# cat          | 2            | 0.07692307692307693    | 0.11538461538461539
# dog          | 1            | 0.038461538461538464   | 0.07692307692307693
# mat          | 2            | 0.07692307692307693    | 0.11538461538461539
# on           | 3            | 0.11538461538461539    | 0.15384615384615385
# rug          | 1            | 0.038461538461538464   | 0.07692307692307693
# sits         | 2            | 0.07692307692307693    | 0.11538461538461539
# sleeps       | 1            | 0.038461538461538464   | 0.07692307692307693
# the          | 6            | 0.23076923076923078    | 0.2692307692307692

# %% [markdown]
# **Category 6 : Bigram Language Model and Laplace smoothing**

# %%
import nltk
from nltk.corpus import brown, reuters
from nltk.util import bigrams
from collections import Counter, defaultdict
import math
from sklearn.datasets import fetch_20newsgroups

nltk.download('brown')
nltk.download('reuters')
nltk.download('punkt')

def preprocess(words):

class BigramModel:
    def __init__(self, corpus):
        self.unigrams = Counter(corpus)
        self.bigrams = Counter(bigrams(corpus))
        self.vocab_size = len(self.unigrams)

    def prob(self, w1, w2):
        return self.bigrams[(w1, w2)] / self.unigrams[w1] if self.unigrams[w1] > 0 else 0

    def laplace(self, w1, w2):
        return (self.bigrams[(w1, w2)] + 1) / (self.unigrams[w1] + self.vocab_size)

    def lidstone(self, w1, w2, gamma=0.1):
        return (self.bigrams[(w1, w2)] + gamma) / (self.unigrams[w1] + gamma * self.vocab_size)

    def interpolation(self, w1, w2, l1=0.7, l2=0.3):
        bigram_p = self.prob(w1, w2)
        unigram_p = self.unigrams[w2] / sum(self.unigrams.values())
        return l1 * bigram_p + l2 * unigram_p

brown_words = preprocess(brown.words()[:5000])

reuters_words = preprocess(reuters.words()[:5000])

news_data = fetch_20newsgroups(subset='train')
news_words = preprocess(" ".join(news_data.data[:50]).split())

ud_words = brown_words

brown_model = BigramModel(brown_words)
reuters_model = BigramModel(reuters_words)
news_model = BigramModel(news_words)
ud_model = BigramModel(ud_words)

test_pairs = [("the", "man"), ("machine", "learning")]

def test_model(model, name):
    print(f"\n==== {name} ====")
    for w1, w2 in test_pairs:
        print(f"\nBigram: ({w1}, {w2})")
        print("No smoothing:", model.prob(w1, w2))
        print("Laplace:", model.laplace(w1, w2))
        print("Lidstone:", model.lidstone(w1, w2))
        print("Interpolation:", model.interpolation(w1, w2))

test_model(brown_model, "Brown Corpus")
test_model(reuters_model, "Reuters Corpus")
test_model(news_model, "Newsgroups Corpus")
test_model(ud_model, "UD Treebank (Simulated)")
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ==== Brown Corpus ====
#
# Bigram: (the, man)
# No smoothing: 0.0
# Laplace: 0.0005851375073142189
# Lidstone: 0.00021537798836958864
# Interpolation: 7.139457401237505e-05
#
# Bigram: (machine, learning)
# No smoothing: 0
# Laplace: 0.0007230657989877079
# Lidstone: 0.0007230657989877079
# Interpolation: 7.139457401237505e-05
#
# ==== Reuters Corpus ====
#
# Bigram: (the, man)
# No smoothing: 0.0
# Laplace: 0.0006770480704129993
# Lidstone: 0.0002915451895043732
# Interpolation: 0.0
#
# Bigram: (machine, learning)
# No smoothing: 0
# Laplace: 0.0007936507936507937
# Lidstone: 0.0007936507936507937
# Interpolation: 0.0
#
# ==== Newsgroups Corpus ====
#
# Bigram: (the, man)
# ...

# %% [markdown]
# **Category 7:**

# %% [markdown]
# Spelling Correction (N-gram + Morphological idea)

# %%
import nltk
from collections import Counter

nltk.download('gutenberg')

words = []

for fileid in nltk.corpus.gutenberg.fileids():
    words.extend(nltk.corpus.gutenberg.words(fileid))

words = [w.lower() for w in words if w.isalpha()]
word_freq = Counter(words)

def edits1(word):
    letters = 'abcdefghijklmnopqrstuvwxyz'
    splits = [(word[:i], word[i:]) for i in range(len(word)+1)]

    deletes = [L + R[1:] for L, R in splits if R]
    inserts = [L + c + R for L, R in splits for c in letters]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]

    return set(deletes + inserts + replaces)

def edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1))

def known(words):
    return set(w for w in words if w in word_freq)

def correct(word):
    candidates = (
        known([word]) or
        known(edits1(word)) or
        known(edits2(word)) or
        [word]
    )
    return max(candidates, key=lambda w: word_freq[w])

print("Correction:", correct("machin"))
print("Correction:", correct("lernning"))
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# Correction: machine
# Correction: leaning

# %% [markdown]
# CBOW (Continuous Bag of Words)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

text = "I love machine learning and deep learning"
words = text.lower().split()
vocab = list(set(words))

word_to_ix = {w:i for i,w in enumerate(vocab)}

window_size = 2
data = []

for i in range(window_size, len(words)-window_size):
    context = [words[i-2], words[i-1], words[i+1], words[i+2]]
    target = words[i]
    data.append((context, target))

class CBOW(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear = nn.Linear(embedding_dim, vocab_size)

    def forward(self, inputs):
        embeds = self.embeddings(inputs).mean(dim=0)
        out = self.linear(embeds)
        return out

model = CBOW(len(vocab), 10)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(50):
    for context, target in data:
        context_ix = torch.tensor([word_to_ix[w] for w in context])
        target_ix = torch.tensor([word_to_ix[target]])

        model.zero_grad()
        output = model(context_ix)
        loss = loss_fn(output.view(1,-1), target_ix)
        loss.backward()
        optimizer.step()

print("Training Complete")
# Out:
# Training Complete

# %% [markdown]
# Skip-Gram Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

text = "I love machine learning and deep learning"
words = text.lower().split()
vocab = list(set(words))

word_to_ix = {w:i for i,w in enumerate(vocab)}

window_size = 2
data = []

for i in range(len(words)):
    for j in range(-window_size, window_size+1):
        if j != 0 and 0 <= i+j < len(words):
            data.append((words[i], words[i+j]))

class SkipGram(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear = nn.Linear(embedding_dim, vocab_size)

    def forward(self, input_word):
        embed = self.embeddings(input_word)
        out = self.linear(embed)
        return out

model = SkipGram(len(vocab), 10)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(50):
    for target, context in data:
        target_ix = torch.tensor([word_to_ix[target]])
        context_ix = torch.tensor([word_to_ix[context]])

        model.zero_grad()
        output = model(target_ix)
        loss = loss_fn(output, context_ix)
        loss.backward()
        optimizer.step()

print("Training Complete")
# Out:
# Training Complete

# %% [markdown]
# **Category 8:**

# %% [markdown]
# TF-IDF Vector Embedding

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = [
    "I love machine learning",
    "Machine learning is amazing",
    "I love coding and machine learning"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

print("Feature Names (Words):\n")
print(vectorizer.get_feature_names_out())
print("\nTF-IDF Matrix:\n")
print(X.toarray())
# Out:
# Feature Names (Words):
#
# ['amazing' 'and' 'coding' 'is' 'learning' 'love' 'machine']
#
# TF-IDF Matrix:
#
# [[0.         0.         0.         0.         0.52284231 0.67325467
#   0.52284231]
#  [0.6088451  0.         0.         0.6088451  0.35959372 0.
#   0.35959372]
#  [0.         0.55249005 0.55249005 0.         0.32630952 0.42018292
#   0.32630952]]

# %% [markdown]
# Cosine Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

corpus = [
    "I love machine learning",
    "Machine learning is amazing",
    "I love coding and machine learning"
]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus)

cos_sim = cosine_similarity(tfidf_matrix)

print("Cosine Similarity Matrix:\n")
print(cos_sim)
# Out:
# Cosine Similarity Matrix:
#
# [[1.         0.37602162 0.62410696]
#  [0.37602162 1.         0.23467771]
#  [0.62410696 0.23467771 1.        ]]

# %% [markdown]
# Pointwise Mutual Information Score

# %%
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter
import math

corpus = [
    "I love machine learning",
    "Machine learning is amazing",
    "I love coding and machine learning"
]

tokens = []
for sentence in corpus:
    tokens.extend(word_tokenize(sentence.lower()))

word_counts = Counter(tokens)
total_words = len(tokens)

bigrams = list(nltk.bigrams(tokens))
bigram_counts = Counter(bigrams)
total_bigrams = len(bigrams)

def compute_pmi(w1, w2):
    p_w1 = word_counts[w1] / total_words
    p_w2 = word_counts[w2] / total_words
    p_w1_w2 = bigram_counts[(w1, w2)] / total_bigrams if (w1, w2) in bigram_counts else 0

    if p_w1_w2 == 0:
        return 0

    return math.log2(p_w1_w2 / (p_w1 * p_w2))

print("PMI Scores:\n")

vocab = list(word_counts.keys())

for i in range(len(vocab)):
    for j in range(i+1, len(vocab)):
        w1, w2 = vocab[i], vocab[j]
        pmi = compute_pmi(w1, w2)

        if pmi > 0:
            print(f"{w1} - {w2} : {round(pmi, 3)}")
# Out:
# PMI Scores:
#
# i - love : 2.914
# love - machine : 1.329
# love - coding : 2.914
# machine - learning : 2.329
# learning - is : 2.329
# is - amazing : 3.914
# coding - and : 3.914

# %% [markdown]
# **Category 9: Word2Vec Embedding model**

# %%
# !pip install gensim umap-learn

import numpy as np
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

sentences = [
    "machine learning is fun",
    "deep learning is powerful",
    "AI is the future",
    "natural language processing is interesting",
    "word embeddings capture meaning"
]

data = [sentence.split() for sentence in sentences]

model = Word2Vec(sentences=data, vector_size=50, window=3, min_count=1, workers=2)

words = list(model.wv.index_to_key)
vectors = np.array([model.wv[word] for word in words])

pca = PCA(n_components=2)
pca_result = pca.fit_transform(vectors)

tsne = TSNE(n_components=2, random_state=42, perplexity=3)
tsne_result = tsne.fit_transform(vectors)

umap_model = umap.UMAP(n_components=2, random_state=42)
umap_result = umap_model.fit_transform(vectors)

def plot_embeddings(result, title):
    plt.figure()
    for i, word in enumerate(words):
        x, y = result[i]
        plt.scatter(x, y)
        plt.text(x, y, word)
    plt.title(title)
    plt.show()

plot_embeddings(pca_result, "PCA")
plot_embeddings(tsne_result, "t-SNE")
plot_embeddings(umap_result, "UMAP")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 37.1 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# **Category 10: Hidden Markov Model for POS Tagging**

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import hmm
from nltk.probability import LidstoneProbDist
nltk.download('treebank')

tagged_sentences = treebank.tagged_sents()[:3000]

trainer = hmm.HiddenMarkovModelTrainer()

tagger = trainer.train_supervised(
    tagged_sentences,
    estimator=lambda fd, bins: LidstoneProbDist(fd, 0.1)
)

sentence = "The bank can guarantee deposits".split()

vocab = set(word for sent in tagged_sentences for word, tag in sent)
sentence = [w if w in vocab else "UNK" for w in sentence]

states = list(set(tag for sent in tagged_sentences for word, tag in sent))

trans_p = tagger._transitions
emit_p = tagger._outputs
start_p = tagger._priors

def forward(obs):
    alpha = [{}]

    for state in states:
        alpha[0][state] = start_p.prob(state) * emit_p[state].prob(obs[0])

    for t in range(1, len(obs)):
        alpha.append({})
        for state in states:
            alpha[t][state] = sum(
                alpha[t-1][prev] *
                trans_p[prev].prob(state) *
                emit_p[state].prob(obs[t])
                for prev in states
            )

    return sum(alpha[-1].values())

def backward(obs):
    beta = [{} for _ in range(len(obs))]

    for state in states:
        beta[-1][state] = 1

    for t in reversed(range(len(obs)-1)):
        for state in states:
            beta[t][state] = sum(
                trans_p[state].prob(next_state) *
                emit_p[next_state].prob(obs[t+1]) *
                beta[t+1][next_state]
                for next_state in states
            )

    return sum(
        start_p.prob(state) *
        emit_p[state].prob(obs[0]) *
        beta[0][state]
        for state in states
    )

def viterbi(obs):
    V = [{}]
    path = {}

    for state in states:
        V[0][state] = start_p.prob(state) * emit_p[state].prob(obs[0])
        path[state] = [state]

    for t in range(1, len(obs)):
        V.append({})
        new_path = {}

        for state in states:
            (prob, prev_state) = max(
                (V[t-1][prev] *
                 trans_p[prev].prob(state) *
                 emit_p[state].prob(obs[t]), prev)
                for prev in states
            )

            V[t][state] = prob
            new_path[state] = path[prev_state] + [state]

        path = new_path

    (prob, state) = max((V[-1][s], s) for s in states)
    return path[state]

print("\nLearning Phase (Parameter Estimation):")

print("\nInitial Probabilities (sample):")
for s in states[:5]:
    print(s, ":", start_p.prob(s))

print("\nTransition Probabilities (sample):")
for s in states[:3]:
    for t in states[:3]:
        print(f"{s} -> {t} :", trans_p[s].prob(t))

print("\nEmission Probabilities (sample):")
for s in states[:3]:
    for w in sentence[:3]:
        print(f"{s} emits {w} :", emit_p[s].prob(w))

print("\nSentence:", sentence)

print("\nForward Probability:")
print(forward(sentence))

print("\nBackward Probability:")
print(backward(sentence))

print("\nViterbi POS Tags:")
print(list(zip(sentence, viterbi(sentence))))
# Out:
# ...
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# Learning Phase (Parameter Estimation):
#
# Initial Probabilities (sample):
# IN : 0.13254536374230066
# # : 3.32944897619444e-05
# VB : 0.0006991842850008324
# CC : 0.05563509239220909
# -NONE- : 0.024338272015981353
#
# Transition Probabilities (sample):
# IN -> IN : 0.015620246802544738
# IN -> # : 0.0009390664885526472
# IN -> VB : 0.00014548917428280453
# # -> IN : 0.0076335877862595426
# # -> # : 0.0076335877862595426
# # -> VB : 0.0076335877862595426
# VB -> IN : 0.10066746363817494
# VB -> # : 4.981071926678622e-05
# VB -> VB : 0.0015441322972703727
#
# Emission Probabilities (sample):
# IN emits The : 1.3209341646412345e-05
# IN emits bank : 1.3209341646412345e-05
# IN emits can : 1.3209341646412345e-05
# # emits The : 0.0076335877862595426
# # emits bank : 0.0076335877862595426
# # emits can : 0.0076335877862595426
# VB emits The : 4.843787842092517e-05
# ...

# %% [markdown]
# **Category 11:**

# %% [markdown]
# Word Sense Disambiguation

# %%
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def preprocess(sentence):
    tokens = word_tokenize(sentence.lower())
    return [w for w in tokens if w.isalpha() and w not in stop_words]

def improved_lesk(sentence, target_word):
    context = set(preprocess(sentence))
    best_sense = None
    max_overlap = 0

    for synset in wordnet.synsets(target_word):
        signature = synset.definition().split()
        for ex in synset.examples():
            signature += ex.split()

        signature = set(w.lower() for w in signature)

        overlap = len(context.intersection(signature))

        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = synset

    return best_sense

def perform_wsd(sentence, target_word):
    sense = improved_lesk(sentence, target_word)

    print("\nSentence:", sentence)
    print("Word:", target_word)

    if sense:
        print("Sense:", sense.name())
        print("Definition:", sense.definition())
    else:
        print("Sense: Not Found")

text1 = "I went to the bank to deposit money"
text2 = "We had a picnic near the bank"

perform_wsd(text1, "bank")
perform_wsd(text2, "bank")
# Out:
# Sentence: I went to the bank to deposit money
# Word: bank
# Sense: depository_financial_institution.n.01
# Definition: a financial institution that accepts deposits and channels the money into lending activities
#
# Sentence: We had a picnic near the bank
# Word: bank
# Sense: bank.n.01
# Definition: sloping land (especially the slope beside a body of water)

# %% [markdown]
# Dependency Parsing and Constituency Parsing

# %%
import nltk
from nltk import word_tokenize, pos_tag
from nltk.tree import Tree
from nltk.parse import ChartParser
from nltk.grammar import CFG

text = "Sundar Pichai is the CEO of Google"

grammar = CFG.fromstring("""
S -> NP VP
VP -> VBZ NP | VBZ NP PP
NP -> NNP | NNP NNP | DT NN | DT NN PP
PP -> IN NP

NNP -> 'Sundar' | 'Pichai' | 'Google'
NN -> 'CEO'
DT -> 'the'
VBZ -> 'is'
IN -> 'of'
""")

parser = ChartParser(grammar)

def constituency_parse(sentence):
    print("\n=== Constituency Parsing ===\n")
    tokens = word_tokenize(sentence)

    for tree in parser.parse(tokens):
        print(tree)
        tree.pretty_print()

def dependency_parse(sentence):
    print("\n=== Dependency Parsing (Basic NLTK Approximation) ===\n")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Simple rule-based dependency (approx)
    for i, (word, tag) in enumerate(pos_tags):
        if tag.startswith('NN'):
            print(f"{word} --> subject/object")
        elif tag.startswith('VB'):
            print(f"{word} --> root (verb)")
        elif tag == 'IN':
            print(f"{word} --> preposition")
        else:
            print(f"{word} --> modifier")

print("\nProcessing Small Dataset...")
constituency_parse(text)
dependency_parse(text)
# Out:
# Processing Small Dataset...
#
# === Constituency Parsing ===
#
# (S
#   (NP (NNP Sundar) (NNP Pichai))
#   (VP (VBZ is) (NP (DT the) (NN CEO)) (PP (IN of) (NP (NNP Google)))))
#                        S
#          ______________|_______
#         |                      VP
#         |           ___________|_______
#         |          |       |           PP
#         |          |       |        ___|____
#         NP         |       NP      |        NP
#    _____|____      |    ___|___    |        |
#  NNP        NNP   VBZ  DT      NN  IN      NNP
#   |          |     |   |       |   |        |
# Sundar     Pichai  is the     CEO  of     Google
#
# (S
#   (NP (NNP Sundar) (NNP Pichai))
#   (VP (VBZ is) (NP (DT the) (NN CEO) (PP (IN of) (NP (NNP Google))))))
#              S
#          ____|_________
#         |              VP
#         |           ___|___
#         |          |       NP
#         |          |    ___|_______
#         |          |   |   |       PP
# ...

# %% [markdown]
# **Category 12: NER**

# %%
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk

# ===== SMALL DATASET =====
text = """
Sundar Pichai is the CEO of Google. He was born in India and works in California.
Microsoft Corporation is based in the United States.
"""

def process_text(data):
    tokens = word_tokenize(data)
    pos_tags = pos_tag(tokens)
    ner_tree = ne_chunk(pos_tags)

    results = []
    for subtree in ner_tree:
        if hasattr(subtree, 'label'):
            entity = " ".join([word for word, tag in subtree.leaves()])
            results.append(f"{entity} --> {subtree.label()}")
    return results

print("\nProcessing Small Dataset...\n")
output = process_text(text)

# ===== OUTPUT =====
print("Named Entities:\n")
for item in output:
    print(item)
# Out:
# Processing Small Dataset...
#
# Named Entities:
#
# Sundar --> PERSON
# Pichai --> PERSON
# CEO of Google --> ORGANIZATION
# India --> GPE
# California --> GPE
# Microsoft Corporation --> PERSON
# United States --> GPE
